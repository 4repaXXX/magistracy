# %%
pip install opencv-python matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 1.6 MB/s eta 0:00:0000:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from matplotlib import pyplot as plt

image = cv2.imread('images/pussy_cat.jpg', cv2.IMREAD_GRAYSCALE)

# cv2.calcHist(image, channels, mask, histSize, ranges)
hist = cv2.calcHist([image], [0], None, [256], [0, 256])

plt.figure()
plt.title("Гистограмма интенсивностей")
plt.xlabel("Интенсивность")
plt.ylabel("Количество пикселей")
plt.plot(hist)
plt.xlim([0, 256])
plt.show()

# %% [markdown]
# ### Спектр
# Он показывает, какие частоты (от низких до высоких) присутствуют в изображении и какова их амплитуда.
# Выполняем преобразование Фурье.(см https://ru.wikipedia.org/wiki/%D0%9F%D1%80%D0%B5%D0%BE%D0%B1%D1%80%D0%B0%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%A4%D1%83%D1%80%D1%8C%D0%B5)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

cat_image = cv2.imread('images/pussy_cat.jpg', cv2.IMREAD_GRAYSCALE)

dft = cv2.dft(np.float32(cat_image), flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))

plt.figure(figsize=(6, 6))
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Спектр Фурье')
plt.axis('off')
plt.show()

# %%
dft[]
# Out:
# array([[[ 3.5021912e+07, -2.7343750e-02],
#         [-4.8204869e+05, -5.6692170e+06],
#         [-5.1631912e+05, -2.8440552e+06],
#         ...,
#         [-9.8165188e+04,  1.3540536e+06],
#         [-5.1631912e+05,  2.8440552e+06],
#         [-4.8204869e+05,  5.6692170e+06]],
#
#        [[-2.5227722e+06,  1.7235429e+06],
#         [ 3.4703245e+06, -4.6206122e+05],
#         [ 3.7219095e+06, -1.8778736e+05],
#         ...,
#         [-4.3352320e+04, -1.4528575e+05],
#         [ 2.6537275e+05, -9.1968550e+05],
#         [-8.9883906e+05,  2.4673955e+06]],
#
#        [[-2.0975638e+05, -1.6551168e+06],
#         [ 7.2679538e+05,  9.2710400e+05],
#         [-3.7572034e+05, -8.5865531e+05],
#         ...,
#         [-3.2684378e+05, -5.9859544e+05],
#         [-2.2013880e+06,  7.6385356e+05],
#         [ 4.7662212e+05,  4.7771547e+05]],
#
#        ...,
#
#        [[ 6.3839438e+05, -1.9523950e+05],
#         [ 2.3121705e+05, -1.1392298e+05],
#         [-5.5663125e+05,  3.2137875e+05],
# ...

# %%
dft_shift[:,:, 2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dft_shift[:,:, 2]
#
# IndexError: index 2 is out of bounds for axis 2 with size 2

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

girl_image = cv2.imread('images/girl.jpg', cv2.IMREAD_GRAYSCALE)

dft = cv2.dft(np.float32(girl_image), flags=cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)

magnitude_spectrum = 20 * np.log(cv2.magnitude(dft_shift[:,:,0], dft_shift[:,:,1]))

plt.figure(figsize=(6, 6))
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Спектр Фурье')
plt.axis('off')
plt.show()
